# %% [markdown]
# <a href="https://colab.research.google.com/github/nimishwork6699/Pandas/blob/main/phase_1.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd

# %%
df=pd.DataFrame([[1,2,3],[4,5,6],[7,8,9] ],columns=["A","B","C"])

# %%
df.head() # here in head section we ncan write 1 and 2 for specific rows showing of 1st and 1to 2 rows
# Out:
#    A  B  C
# 0  1  2  3
# 1  4  5  6
# 2  7  8  9

# %%
df.tail(1) # for printing the last 2 or bottom two rows
# Out:
#    A  B  C
# 2  7  8  9

# %%
df.index # for index
# Out:
# RangeIndex(start=0, stop=3, step=1)

# %%
df.index.tolist()
# Out:
# [0, 1, 2]

# %%
df=pd.DataFrame([[1,2,3],[4,5,6],[7,8,9] ],columns=["A","B","C"],index=["X","Y","Z"])

# %%
df
# Out:
#    A  B  C
# X  1  2  3
# Y  4  5  6
# Z  7  8  9

# %%
df.index
# Out:
# Index(['X', 'Y', 'Z'], dtype='object')

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 3 entries, X to Z
# Data columns (total 3 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   A       3 non-null      int64
#  1   B       3 non-null      int64
#  2   C       3 non-null      int64
# dtypes: int64(3)
# memory usage: 204.0+ bytes

# %%
df.describe() # help to use more values in it
# Out:
#          A    B    C
# count  3.0  3.0  3.0
# mean   4.0  5.0  6.0
# std    3.0  3.0  3.0
# min    1.0  2.0  3.0
# 25%    2.5  3.5  4.5
# 50%    4.0  5.0  6.0
# 75%    5.5  6.5  7.5
# max    7.0  8.0  9.0

# %%
df.nunique()
# Out:
# A    3
# B    3
# C    3
# dtype: int64

# %%
df.shape
# Out:
# (3, 3)
